# %%
import numpy as np
import os
from DH_dynamics import dh_robot_config
from JS_control import *
import matplotlib.pyplot as plt
from pyrep import PyRep
from arm import CtRobot
from pyrep.backend import vrep
import sympy as sp
from pyrep.const import JointMode
import time

# %matplotlib notebook

pr = PyRep()

# %%
param = ['D', 'a', 'alpha', 'theta', 'num_joints', 'jointType', 'Tbase', 'L', 'M']
config = dict()
for i in range(len(param)):
    config[param[i]] = np.load('./robot_config/config_ct_7DOF/%s.npy'%param[i])

# %%
robot = dh_robot_config(int(config['num_joints']), config['alpha'], config['theta'], config['D'], config['a'], 
                                                config['jointType'], config['Tbase'], config['L'], config['M'])
robot.initKinematicTransforms()
# Out:
# Calculating link 0
# Calculating link 1
# Calculating link 2
# Calculating link 3
# Calculating link 4
# Calculating link 5
# Calculating link 6
# Calculating link 7
# Calculating Mass and Gravity Matrix...
# -------------------------------------------------------------------
# Calculation complete

# %% [markdown]
# ## Simulation Set up
#
# ### For all joints

# %%
pr.launch(os.getcwd() + '/Modified_DH_ct_7DOF.ttt', headless=False)
ct_robot = CtRobot()

xyz = np.array([0, 0, 0])

# %%
dt = 0.01
pr.set_simulation_timestep(dt)

# %%
# Starting simulation
pr.start()
err_pos = []
err_vel = []
mespos = []
depos = []

# Set up joints to be in force control mode
for i in range(ct_robot._num_joints):
    ct_robot.joints[i].set_joint_mode(JointMode.FORCE)
    ct_robot.joints[i].set_control_loop_enabled(False)
    ct_robot.joints[i].set_motor_locked_at_zero_velocity(True)
for j in range(1, ct_robot._num_joints + 1):
    ct_robot.arms[i].set_dynamic(True)
ct_robot.arms[0].set_dynamic(False)
pr.step()

# Desired trajectory
end_time = 4
t_dic = np.linspace(0, end_time, num=int(end_time/dt), endpoint=True)
t = sp.Symbol('t')
# disired trajectory of position for each joint

# # Sine wave activation
# traj = [
#     0.0*sp.sin(t*4),
#     0.0*sp.cos(t*4),
#     (0/180*np.pi)*sp.sin(t*np.pi),
#     (0/180*np.pi)*sp.sin(t*4),
#     (30/180*np.pi)*sp.cos(t*4),
#     (0/180*np.pi)*sp.cos(t*4),
#     0.00*sp.sin(t/2)
# ]

# Step response
traj = [
    0.01 * sp.ones(1),
    0.01 * sp.ones(1),
    (15/180*np.pi)*sp.ones(1),
    (-30/180*np.pi)*sp.ones(1),
    (45/180*np.pi)*sp.ones(1),
    (20/180*np.pi)*sp.ones(1),
    0.005*sp.ones(1)
]

pos = [sp.lambdify(t, i) for i in traj]
vel = [sp.lambdify(t, i.diff(t)) for i in traj]
acc = [sp.lambdify(t, i.diff(t).diff(t)) for i in traj]

# Gain
# kp = np.diag([100, 100, 100, 100, 100, 100, 100])
# kv = np.diag([0, 0, 0, 0, 0, 0, 0])
kp = np.diag([10, 10, 200, 2.5, 1, 0.4, 0.4])
kv = np.diag([0.8, 0.8, 160, 10, 7, 2, 3])

# Simulation
for i in range(int(end_time/dt)):
    posd = [float(j(t_dic[i])) for j in pos]
    veld = np.array([j(t_dic[i]) for j in vel]).squeeze()
    accd = np.array([j(t_dic[i]) for j in acc]).squeeze()
    posm = np.array(ct_robot.get_joint_positions())
    velm = np.array(ct_robot.get_joint_velocities())
    ts1 = time.time()
    tau = cacl_tau_GravityCompensation(robot, kp, kv, posd, posm, veld, velm, xyz, accd)
    te = time.time()
    print('Time for computing torque: %.6f'%(te-ts1))
    
    ts2 = time.time()
    ct_robot.set_joint_target_velocities((np.sign(tau)*1000000).tolist())
    ct_robot.set_joint_forces(np.abs(tau).tolist())
    pr.step()
    measure_pos = np.array(ct_robot.get_joint_positions())
    measure_vel = np.array(ct_robot.get_joint_velocities())
    te1 = time.time()
    print('Time for communicating with V-REP: %.6f'%(te1-ts2))
    
    # Record error of each joint
    err_pos.append(posd - measure_pos)
    err_vel.append(veld - measure_vel)
    depos.append(posd)
    mespos.append(measure_pos)
# Out:
# Time for computing torque: 0.001148
# Time for communicating with V-REP: 0.010845
# Time for computing torque: 0.001091
# Time for communicating with V-REP: 0.009404
# Time for computing torque: 0.001204
# Time for communicating with V-REP: 0.018935
# Time for computing torque: 0.001102
# Time for communicating with V-REP: 0.008044
# Time for computing torque: 0.001037
# Time for communicating with V-REP: 0.017688
# Time for computing torque: 0.001097
# Time for communicating with V-REP: 0.015779
# Time for computing torque: 0.001104
# Time for communicating with V-REP: 0.014647
# Time for computing torque: 0.001063
# Time for communicating with V-REP: 0.014541
# Time for computing torque: 0.001069
# Time for communicating with V-REP: 0.016730
# Time for computing torque: 0.001126
# Time for communicating with V-REP: 0.014717
# Time for computing torque: 0.001061
# Time for communicating with V-REP: 0.014657
# Time for computing torque: 0.001100
# Time for communicating with V-REP: 0.014762
# Time for computing torque: 0.001120
# Time for communicating with V-REP: 0.014559
# Time for computing torque: 0.001087
# Time for communicating with V-REP: 0.018176
# Time for computing torque: 0.001060
# Time for communicating with V-REP: 0.015581
# Time for computing torque: 0.001057
# Time for communicating with V-REP: 0.015179
# Time for computing torque: 0.001076
# Time for communicating with V-REP: 0.017981
# Time for computing torque: 0.001044
# Time for communicating with V-REP: 0.015861
# Time for computing torque: 0.001057
# Time for communicating with V-REP: 0.014653
# Time for computing torque: 0.001053
# Time for communicating with V-REP: 0.014547
# Time for computing torque: 0.001047
# Time for communicating with V-REP: 0.020472
# Time for computing torque: 0.001124
# Time for communicating with V-REP: 0.014680
# Time for computing torque: 0.001096
# Time for communicating with V-REP: 0.015811
# Time for computing torque: 0.001061
# Time for communicating with V-REP: 0.014612
# Time for computing torque: 0.001048
# Time for communicating with V-REP: 0.020075
# Time for computing torque: 0.001103
# Time for communicating with V-REP: 0.013963
# Time for computing torque: 0.001177
# Time for communicating with V-REP: 0.016764
# Time for computing torque: 0.001072
# Time for communicating with V-REP: 0.018731
# Time for computing torque: 0.001050
# Time for communicating with V-REP: 0.013390
# Time for computing torque: 0.001102
# Time for communicating with V-REP: 0.015751
# Time for computing torque: 0.001079
# Time for communicating with V-REP: 0.019125
# Time for computing torque: 0.001057
# Time for communicating with V-REP: 0.013496
# Time for computing torque: 0.001100
# Time for communicating with V-REP: 0.014653
# Time for computing torque: 0.001061
# Time for communicating with V-REP: 0
# Time for computing torque: 0.001053
# Time for communicating with V-REP: 0.013706
# Time for computing torque: 0.001079
# Time for communicating with V-REP: 0.014905
# Time for computing torque: 0.001052
# Time for communicating with V-REP: 0.019841
# Time for computing torque: 0.001021
# Time for communicating with V-REP: 0.012296
# Time for computing torque: 0.001053
# Time for communicating with V-REP: 0.016971
# Time for computing torque: 0.001154
# Time for communicating with V-REP: 0.016780
# Time for computing torque: 0.001061
# Time for communicating with V-REP: 0.014538
# Time for computing torque: 0.001078
# Time for communicating with V-REP: 0.018947
# Time for computing torque: 0.001064
# Time for communicating with V-REP: 0.014477
# Time for computing torque: 0.001060
# Time for communicating with V-REP: 0.013470
# Time for computing torque: 0.001042
# Time for communicating with V-REP: 0.013436
# Time for computing torque: 0.001081
# Time for communicating with V-REP: 0.016673
# Time for computing torque: 0.001084
# Time for communicating with V-REP: 0.018069
# Time for computing torque: 0.001132
# Time for communicating with V-REP: 0.012835
# Time for computing torque: 0.001180
# Time for communicating with V-REP: 0.015571
# Time for computing torque: 0.001076
# Time for communicating with V-REP: 0.014476
# Time for computing torque: 0.001056
# Time for communicating with V-REP: 0.021048
# Time for computing torque: 0.001071
# Time for communicating with V-REP: 0.013485
# Time for computing torque: 0.001061
# Time for communicating with V-REP: 0.013555
# Time for computing torque: 0.001017
# Time for communicating with V-REP: 0.017905
# Time for computing torque: 0.001085
# Time for communicating with V-REP: 0.016851
# Time for computing torque: 0.001054
# Time for communicating with V-REP: 0.013789
# Time for computing torque: 0.001077
# Time for communicating with V-REP: 0.014665
# Time for computing torque: 0.001044
# Time for communicating with V-REP: 0.016613
# Time for computing torque: 0.001074
# Time for communicating with V-REP: 0.015817
# Time for computing torque: 0.001034
# Time for communicating with V-REP: 0.013620
# Time for computing torque: 0.001117
# Time for communicating with V-REP: 0.013517

# %%
# Change Unit
err_pos = np.array(err_pos)
mespos = np.array(mespos)
depos = np.array(depos)

for name in ['err_pos', 'mespos', 'depos']:
    x = eval(name)
    x[:, 0:1] = x[:, 0:1]*1000
    x[:, 1:2] = x[:, 1:2]*1000
    x[:, 6:7] = x[:, 6:7]*1000
    x[:, 2:3] = x[:, 2:3]*180/np.pi
    x[:, 3:4] = x[:, 3:4]*180/np.pi
    x[:, 4:5] = x[:, 4:5]*180/np.pi
    x[:, 5:6] = x[:, 5:6]*180/np.pi

# %%
# Plot error of position from joint to joint
plt.figure(figsize=(18,10))
plt.suptitle('Error')
for i in range(6):
    plt.subplot(2,4,i+1)
    plt.title('Joint%d'%(i+1))
    plt.plot(np.array(err_pos)[:, i])
    if i in [0,1,6]:
        plt.ylabel('mm')
    else:
        plt.ylabel('deg')

# %%
# Plot error of position from joint to joint
plt.figure(figsize=(18,10))
plt.suptitle('Absoluter value')
for i in range(6):
    plt.subplot(2,4,i+1)
    plt.title('Joint%d'%(i+1))
    plt.plot(mespos[:, i], label='mesaured')
    plt.plot(depos[:, i], label='desired')
    plt.legend()
    if i in [0,1,6]:
        plt.ylabel('mm')
    else:
        plt.ylabel('deg')

# %%
pr.stop()

# %%
pr.shutdown()
